# %%
# !pip install openrouteservice

# %%
API_KEY = "5b3ce3597851110001cf624878705a086d2143a1ab33154d9a604cac"

# %%
import openrouteservice

coords = ((8.34234,48.23424),
          (8.34423,48.26424), 
          (8.34523,48.24424),
          (8.41423,48.21424))

client = openrouteservice.Client(key=API_KEY) # Specify your personal API key
routes = client.directions(coords, profile='cycling-regular', optimize_waypoints=True)

print(routes)
# Out:
# {'routes': [{'summary': {'distance': 18997.8, 'duration': 4604.4}, 'segments': [{'distance': 2022.5, 'duration': 497.3, 'steps': [{'distance': 19.3, 'duration': 5.8, 'type': 11, 'instruction': 'Head southwest', 'name': '-', 'way_points': [0, 1]}, {'distance': 157.4, 'duration': 56.7, 'type': 0, 'instruction': 'Turn left', 'name': '-', 'way_points': [1, 10]}, {'distance': 64.4, 'duration': 12.9, 'type': 0, 'instruction': 'Turn left onto Benatweg', 'name': 'Benatweg', 'way_points': [10, 15]}, {'distance': 56.7, 'duration': 11.3, 'type': 5, 'instruction': 'Turn slight right onto Benatweg', 'name': 'Benatweg', 'way_points': [15, 18]}, {'distance': 457.5, 'duration': 91.5, 'type': 12, 'instruction': 'Keep left onto Imbrand', 'name': 'Imbrand', 'way_points': [18, 44]}, {'distance': 670.2, 'duration': 134.0, 'type': 2, 'instruction': 'Turn sharp left onto Imbrand', 'name': 'Imbrand', 'way_points': [44, 65]}, {'distance': 459.4, 'duration': 137.8, 'type': 1, 'instruction': 'Turn right', 'name': '-', 'way_points': [65, 75]}, {'distance': 97.5, 'duration': 29.2, 'type': 4, 'instruction': 'Turn slight left', 'name': '-', 'way_points': [75, 78]}, {'distance': 40.1, 'duration': 18.0, 'type': 2, 'instruction': 'Turn sharp left', 'name': '-', 'way_points': [78, 79]}, {'distance': 0.0, 'duration': 0.0, 'type': 10, 'instruction': 'Arrive at your destination, on the right', 'name': '-', 'way_points': [79, 79]}]}, {'distance': 4817.8, 'duration': 1307.5, 'steps': [{'distance': 123.2, 'duration': 55.4, 'type': 11, 'instruction': 'Head southeast', 'name': '-', 'way_points': [79, 85]}, {'distance': 142.5, 'duration': 42.8, 'type': 4, 'instruction': 'Turn slight left', 'name': '-', 'way_points': [85, 88]}, {'distance': 430.7, 'duration': 129.2, 'type': 0, 'instruction': 'Turn left', 'name': '-', 'way_points': [88, 98]}, {'distance': 383.2, 'duration': 115.0, 'type': 1, 'instruction': 'Turn right', 'name': '-', 'way_points': [98, 112]}, {'distance': 217.9, 'duration': 49.0, 'type': 0, 'instruction': 'Turn left', 'name': '-', 'way_points': [112, 115]}, {'distance': 567.0, 'duration': 127.6, 'type': 13, 'instruction': 'Keep right', 'name': '-', 'way_points': [115, 128]}, {'distance': 536.7, 'duration': 120.7, 'type': 5, 'instruction': 'Turn slight right', 'name': '-', 'way_points': [128, 140]}, {'distance': 247.6, 'duration': 55.7, 'type': 13, 'instruction': 'Keep right', 'name': '-', 'way_points': [140, 149]}, {'distance': 293.7, 'duration': 75.5, 'type': 1, 'instruction': 'Turn right', 'name': '-', 'way_points': [149, 159]}, {'distance': 252.4, 'duration': 64.9, 'type': 12, 'instruction': 'Keep left', 'name': '-', 'way_points': [159, 165]}, {'distance': 355.8, 'duration': 91.5, 'type': 13, 'instruction': 'Keep right', 'name': '-', 'way_points': [165, 173]}, {'distance': 14.8, 'duration': 4.4, 'type': 5, 'instruction': 'Turn slight right', 'name': '-', 'way_points': [173, 174]}, {'distance': 572.1, 'duration': 171.6, 'type': 12, 'instruction': 'Keep left', 'name': '-', 'way_points': [174, 190]}, {'distance': 37.6, 'duration': 11.3, 'type': 0, 'instruction': 'Turn left', 'name': '-', 'way_points': [190, 193]}, {'distance': 469.9, 'duration': 141.0, 'type': 12, 'instruction': 'Keep left', 'name': '-', 'way_points': [193, 207]}, {'distance': 172.7, 'duration': 51.8, 'type': 2, 'instruction': 'Turn sharp left', 'name': '-', 'way_points': [207, 212]}, {'distance': 0.0, 'duration': 0.0, 'type': 10, 'instruction': 'Arrive at your destination, on the left', 'name': '-', 'way_points': [212, 212]}]}, {'distance': 12157.5, 'duration': 2799.6, 'steps': [{'distance': 1166.1, 'duration': 349.8, 'type': 11, 'instruction': 'Head southeast', 'name': '-', 'way_points': [212, 241]}, {'distance': 28.9, 'duration': 8.7, 'type': 3, 'instruction': 'Turn sharp right', 'name': '-', 'way_points': [241, 242]}, {'distance': 969.7, 'duration': 290.9, 'type': 12, 'instruction': 'Keep left', 'name': '-', 'way_points': [242, 273]}, {'distance': 628.8, 'duration': 188.6, 'type': 1, ' ...
